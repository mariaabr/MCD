# %% [markdown]
# ### LAB: Linear regression. Ridge regression. Lasso regression
#
# - Hyperparameter choice, Regularization
#
# We will use Boston Housing dataset: 506 samples and 13 feature variables in this dataset. The objective is to predict the average price of houses in Boston (in 1970s) using the given features.

# %%
import sklearn as sk

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns 

from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso

import sklearn.metrics as metrics
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score, GridSearchCV

sk.__version__
# Out:
# '1.4.2'

# %%
boston = pd.read_csv("BostonHousing.csv")

target = boston['medv']
print(target.shape)

# print the size (shape) of matrix boston
print("Matrix boston shape:", boston.shape)

boston.head()
# Out:
# (506,)
# Matrix boston shape: (506, 14)
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         b  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %% [markdown]
# The prices of the house indicated by the variable MEDV is the target variable and the remaining are the feature variables based on which we will predict the value of a house.

# %% [markdown]
# - CRIM: Per capita crime rate by town
# - ZN: Proportion of residential land zoned for lots over 25,000 sq. ft
# - INDUS: Proportion of non-retail business acres per town
# - CHAS: Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
# - NOX: Nitric oxide concentration (parts per 10 million)
# - RM: Average number of rooms per dwelling
# - AGE: Proportion of owner-occupied units built prior to 1940
# - DIS: Weighted distances to five Boston employment centers
# - RAD: Index of accessibility to radial highways
# - TAX: Full-value property tax rate per USD 10,000
# - PTRATIO: Pupil-teacher ratio by town
# - B: 1000(Bk — 0.63)², where Bk is the proportion of people of African American descent by town
# - LSTAT: Percentage of lower status of the population
# - MEDV: Median value of owner-occupied homes in $1000s

# %% [markdown]
# ### Data preprocessing
# After loading the data, it’s a good practice to see if there are any missing values in the data. We count the number of missing values for each feature using isnull()

# %%
boston.isnull().sum()
# Out:
# crim       0
# zn         0
# indus      0
# chas       0
# nox        0
# rm         0
# age        0
# dis        0
# rad        0
# tax        0
# ptratio    0
# b          0
# lstat      0
# medv       0
# dtype: int64

# %% [markdown]
# ### Exploratory Data Analysis
# Exploratory Data Analysis is an important step before training a model.
#
# Plot the distribution of the target variable MEDV with funciton histplot from package sns

# %%
sns.histplot(target)
# Out:
# <Axes: xlabel='medv', ylabel='Count'>

# %% [markdown]
# ### Correlation matrix
# The correlation matrix measures the linear relationships between the variables. It can be computed by using the corr function from pandas library.
# The correlation coefficient ranges from -1 to 1. If the value is close to 1, there is a strong positive correlation between the two variables. When it is close to -1, the variables have a strong negative correlation.

# %%
correlation_matrix = boston.corr().round(2)
correlation_matrix
# Out:
#          crim    zn  indus  chas   nox    rm   age   dis   rad   tax  ptratio  \
# crim     1.00 -0.20   0.41 -0.06  0.42 -0.22  0.35 -0.38  0.63  0.58     0.29
# zn      -0.20  1.00  -0.53 -0.04 -0.52  0.31 -0.57  0.66 -0.31 -0.31    -0.39
# indus    0.41 -0.53   1.00  0.06  0.76 -0.39  0.64 -0.71  0.60  0.72     0.38
# chas    -0.06 -0.04   0.06  1.00  0.09  0.09  0.09 -0.10 -0.01 -0.04    -0.12
# nox      0.42 -0.52   0.76  0.09  1.00 -0.30  0.73 -0.77  0.61  0.67     0.19
# rm      -0.22  0.31  -0.39  0.09 -0.30  1.00 -0.24  0.21 -0.21 -0.29    -0.36
# age      0.35 -0.57   0.64  0.09  0.73 -0.24  1.00 -0.75  0.46  0.51     0.26
# dis     -0.38  0.66  -0.71 -0.10 -0.77  0.21 -0.75  1.00 -0.49 -0.53    -0.23
# rad      0.63 -0.31   0.60 -0.01  0.61 -0.21  0.46 -0.49  1.00  0.91     0.46
# tax      0.58 -0.31   0.72 -0.04  0.67 -0.29  0.51 -0.53  0.91  1.00     0.46
# ptratio  0.29 -0.39   0.38 -0.12  0.19 -0.36  0.26 -0.23  0.46  0.46     1.00
# ...

# %%
# Use the heatmap function from the seaborn library to plot the correlation matrix.
# annot = True to print the values inside the square
sns.heatmap(correlation_matrix, annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ### Feature selection
#
# To fit a linear regression model, we select those features which have a high correlation with the target variable MEDV. By looking at the correlation matrix we can see that RM has a strong positive correlation with MEDV (0.7) where as LSTAT has a high negative correlation with MEDV(-0.74).
# An important point in selecting features for a linear regression model is to check for multi-co-linearity. The features RAD, TAX have a correlation of 0.91. These feature pairs are strongly correlated to each other. It is recomended not select these features together for training the model.  Same goes for features DIS and AGE which have a correlation of -0.75.
# Now we will choose only RM and LSTAT as our features. Using a scatter plot let’s see how these features vary with MEDV.

# %%
plt.figure(figsize=(20, 5))

features = ['lstat', 'rm']
target = boston['medv']

for i, col in enumerate(features):
    plt.subplot(1, len(features) , i+1)
    x = boston[col]
    y = target
    plt.scatter(x, y, marker='o')
    #plt.title(col)
    plt.xlabel(col)
    plt.ylabel('MEDV')

# %%
X = pd.DataFrame([boston['lstat'], boston['rm']]).T
Y = boston['medv']

#Print the size (shape) of X and Y
print("X shape:", X.shape)
print("Y shape:", Y.shape)
# Out:
# X shape: (506, 2)
# Y shape: (506,)

# %% [markdown]
# ### Split the data into training and testing sets
# Train the model with 80% of the samples and test with the remaining 20%.  Use train_test_split function provided by scikit-learn library.
# Print the sizes of the training and test set to verify if the splitting has occurred properly.
#
# Choose random_state = 5 in order to compare the results.

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state = 5)

# check the dimensions of X_train, X_test, Y_train, Y_test
print("X train shape:", X_train.shape)
print("X test shape:", X_test.shape)
print("Y train shape:", Y_train.shape)
print("Y test shape:", Y_test.shape)

# standardize the data
mean = X_train.mean(axis=0)
std = X_train.std(axis=0)
X_train = (X_train-mean )/std

# NOTE: Test data is standardized with mean and std computed from training data !!!
X_test = (X_test-mean )/std

print("X_train normalized:\n", X_train)
print("X_test normalized:\n", X_test)
# Out:
# X train shape: (404, 2)
# X test shape: (102, 2)
# Y train shape: (404,)
# Y test shape: (102,)
# X_train normalized:
#          lstat        rm
# 33   0.834253 -0.847783
# 283 -1.323854  2.358885
# 418  1.156762 -0.478338
# 502 -0.482775 -0.243106
# 402  1.112719  0.166748
# ..        ...       ...
# 486  0.355463 -0.251764
# 189 -1.007028  1.293844
# 495  0.727698 -0.892521
# 206 -0.214254  0.054182
# 355 -0.981455 -0.508644
#
# [404 rows x 2 columns]
# X_test normalized:
#          lstat        rm
# 226 -1.328116  2.527733
# 292 -1.105060  0.492898
# 90  -0.521135  0.185508
# 373  3.167112 -1.995083
# 273 -0.837960  2.024075
# ..        ...       ...
# 349 -0.935991  0.938830
# 212  0.504641 -0.694810
# 156  0.520269 -1.466892
# 480 -0.246931 -0.067042
# 248 -0.420262  0.208599
#
# [102 rows x 2 columns]

# %% [markdown]
# ### Model 1: Linear regression model
#
# Use scikit-learn’s LinearRegression to train the model.
#
# - model= define the LinearRegression operator.
# - model.fit(?,?) with the training data

# %%
lin_model = LinearRegression()
lin_model.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### Evaluate Model 1 performance: RMSE, MSE, R2-score
#
# - model.predict(?) for the training data
# - compute mean_squared_error
# - compute r2_score
# - compute root (np.sqrt) mean_squared_error
# - print those metrics

# %%
# model evaluation for train set
y_train_predict = lin_model.predict(X_train)
rmse = (np.sqrt(mean_squared_error(Y_train, y_train_predict)))
mse = mean_squared_error(Y_train, y_train_predict)
r2 = r2_score(Y_train, y_train_predict)

print("The model performance for training set with linear model")
print("--------------------------------------")
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
print('MSE is {}'.format(mse))
print("\n")

# Compute the same metrics for the test data
y_test_predict = lin_model.predict(X_test)
rmse = (np.sqrt(mean_squared_error(Y_test, y_test_predict)))
mse = mean_squared_error(Y_test, y_test_predict)
r2 = r2_score(Y_test, y_test_predict)

print("The model performance for testing set with linear model")
print("--------------------------------------")
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
print('MSE is {}'.format(mse))
print("\n")
# Out:
# The model performance for training set with linear model
# --------------------------------------
# RMSE is 5.6371293350711955
# R2 score is 0.6300745149331701
# MSE is 31.777227140320214
#
#
# The model performance for testing set with linear model
# --------------------------------------
# RMSE is 5.137400784702911
# R2 score is 0.6628996975186952
# MSE is 26.39288682266609

# %% [markdown]
# ###  Model 2: Ridge regression model
#
# Apply Ridge regression model and choose the regularization hyper-parameter.
#
# In class we call it *lambda* but in sklearn it is configured via “alpha” argument. Default value = 1.0.
#
# Define the Ridge operator and a range of “alpha” values.
#
# Call GridSearchCV. Parameters are set based on some score function. By default these are the sklearn.metrics.accuracy_score for classification and sklearn.metrics.r2_score for regression.

# %%
ridge = Ridge()
parameters = {'alpha':[0.0001, 0.001,0.01,0.1,1,10]}

ridge_regressor = GridSearchCV(ridge,parameters, cv=5)

ridge_regressor.fit(X_train,Y_train)

print(ridge_regressor.best_params_)
# Out:
# {'alpha': 10}

# %% [markdown]
# ### Evaluate Model 2 performance: RMSE, MSE, R2-score
#
# Follow the same sequence as with Model 1.

# %%
# Compute RMSE, R2 score, MSE for the training data
y_train_predict = ridge_regressor.predict(X_train)
rmse = (np.sqrt(mean_squared_error(Y_train, y_train_predict)))
mse = mean_squared_error(Y_train, y_train_predict)
r2 = r2_score(Y_train, y_train_predict)

print("The model performance for training set with ridge regressor")
print("--------------------------------------")
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
print('MSE is {}'.format(mse))
print("\n")

# Compute RMSE, R2 score, MSE for the testing data
y_test_predict = ridge_regressor.predict(X_test)
rmse = (np.sqrt(mean_squared_error(Y_test, y_test_predict)))
mse = mean_squared_error(Y_test, y_test_predict)
r2 = r2_score(Y_test, y_test_predict)

print("The model performance for testing set with ridge regressor")
print("--------------------------------------")
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
print('MSE is {}'.format(mse))
print("\n")
# Out:
# The model performance for training set with ridge regressor
# --------------------------------------
# RMSE is 5.638462108272917
# R2 score is 0.6298995730340575
# MSE is 31.792254946429473
#
#
# The model performance for testing set with ridge regressor
# --------------------------------------
# RMSE is 5.103367463884201
# R2 score is 0.6673512255502241
# MSE is 26.044359471431864

# %% [markdown]
# ###  Model 3: Lasso regression model
#
# Apply Lasso regression model and choose the regularization hyper-parameter.
# Follow the same sequence as for Model 2.

# %%
lasso = Lasso()

# what is the best alpha ?
parameters = {'alpha':[0.0001, 0.001,0.01,0.1,1,10]}

lasso_regressor = GridSearchCV(lasso,parameters, cv=5)

lasso_regressor.fit(X_train,Y_train)

print(lasso_regressor.best_params_)
# Out:
# {'alpha': 0.1}

# %% [markdown]
# ### Evaluate Model 3 performance: RMSE, MSE, R2-score
#
# Follow the same sequence as with Model 1.

# %%
# model evaluation for training set
y_train_predict = lasso_regressor.predict(X_train)
rmse = (np.sqrt(mean_squared_error(Y_train, y_train_predict)))
mse = mean_squared_error(Y_train, y_train_predict)
r2 = r2_score(Y_train, y_train_predict)

print("The model performance for training set with lasso regressor")
print("--------------------------------------")
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
print('MSE is {}'.format(mse))
print("\n")

# model evaluation for testing set
y_test_predict = lasso_regressor.predict(X_test)
rmse = (np.sqrt(mean_squared_error(Y_test, y_test_predict)))
mse = mean_squared_error(Y_test, y_test_predict)
r2 = r2_score(Y_test, y_test_predict)

print("The model performance for testing set with lasso regressor")
print("--------------------------------------")
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
print('MSE is {}'.format(mse))
print("\n")
# Out:
# The model performance for training set with lasso regressor
# --------------------------------------
# RMSE is 5.638253159911876
# R2 score is 0.6299270026569868
# MSE is 31.78989869525626
#
#
# The model performance for testing set with lasso regressor
# --------------------------------------
# RMSE is 5.120934108789315
# R2 score is 0.6650572186490171
# MSE is 26.223966146561818

# %% [markdown]
# ### Regression models with all features
#
# Compare the performance of Ridge and Lasso Regression when trained with all features.

# %%
Xall = boston.values[:, :13]

print(Xall.shape)  #(506, 13)
print(Y.shape)
# Out:
# (506, 13)
# (506,)

# %%
# Split data into train and test sets
Xall_train, Xall_test, Y_train, Y_test = train_test_split(Xall, Y, test_size = 0.2, random_state = 5)

# check the dimensions of X_train, X_test, Y_train, Y_test
print("Xall train shape:", Xall_train.shape)
print("Xall test shape:", Xall_test.shape)
print("Y train shape:", Y_train.shape)
print("Y test shape:", Y_test.shape)

# standardize the data
mean = Xall_train.mean(axis=0)
std = Xall_train.std(axis=0)
Xall_train = (Xall_train-mean )/std

# NOTE: Test data is standardized with mean and std computed from training data !!!
Xall_test = (Xall_test-mean )/std

print("Xall_train normalized:\n", Xall_train)
print("Xall_test normalized:\n", Xall_test)
# Out:
# Xall train shape: (404, 13)
# Xall test shape: (102, 13)
# Y train shape: (404,)
# Y test shape: (102,)
# Xall_train normalized:
#  [[-2.76469903e-01 -5.07766334e-01 -4.02011945e-01 ...  1.17561917e+00
#   -3.01968083e-04  8.35287872e-01]
#  [-4.07463681e-01  3.33136528e+00 -1.43188822e+00 ... -2.20285923e+00
#    4.12907260e-01 -1.32549534e+00]
#  [ 8.06483214e+00 -5.07766334e-01  1.07815655e+00 ...  8.10378266e-01
#   -3.84927565e+00  1.15819623e+00]
#  ...
#  [-3.88566725e-01 -5.07766334e-01 -1.71664438e-01 ...  3.53827130e-01
#    3.87833612e-01  7.28600090e-01]
#  [-3.82724087e-01 -5.07766334e-01 -3.79142727e-02 ...  7.98964487e-02
#    4.05598798e-01 -2.14519905e-01]
#  [-3.96910057e-01  2.90479510e+00 -1.32786031e+00 ...  1.63217031e+00
#    1.93878260e-01 -9.82671938e-01]]
# Xall_test normalized:
#  [[-0.36515584 -0.50776633 -0.69031786 ... -0.46796491  0.32138282
#   -1.32976286]
#  [-0.40502752  2.9047951  -0.87608198 ...  0.35382713  0.42842369
#   -1.10642977]
# ...

# %% [markdown]
# ### Model 4 - Ridge Regression with all features

# %%
ridge = Ridge()
parameters = {'alpha':[0.0001, 0.001,0.01,0.1,1,10]}

ridge_regressor = GridSearchCV(ridge,parameters, cv=5)

ridge_regressor.fit(Xall_train,Y_train)

print(ridge_regressor.best_params_)
# Out:
# {'alpha': 10}

# %%
# model evaluation for training set
# Compute RMSE, R2 score, MSE for the training data
y_train_predict = ridge_regressor.predict(Xall_train)
rmse = (np.sqrt(mean_squared_error(Y_train, y_train_predict)))
mse = mean_squared_error(Y_train, y_train_predict)
r2 = r2_score(Y_train, y_train_predict)

print("The model performance for training set with ridge regressor")
print("--------------------------------------")
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
print('MSE is {}'.format(mse))
print("\n")

# model evaluation for testing set
# Compute RMSE, R2 score, MSE for the testing data
y_test_predict = ridge_regressor.predict(Xall_test)
rmse = (np.sqrt(mean_squared_error(Y_test, y_test_predict)))
mse = mean_squared_error(Y_test, y_test_predict)
r2 = r2_score(Y_test, y_test_predict)

print("The model performance for testing set with ridge regressor")
print("--------------------------------------")
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
print('MSE is {}'.format(mse))
print("\n")
# Out:
# /home/rafaela/anaconda3/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but Ridge was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[62], line 3
#       1 # model evaluation for training set
#       2 # Compute RMSE, R2 score, MSE for the training data
# ----> 3 y_train_predict = ridge_regressor.predict(Xall_train)
#       4 rmse = (np.sqrt(mean_squared_error(Y_train, y_train_predict)))
#       5 mse = mean_squared_error(Y_train, y_train_predict)
#
# File ~/anaconda3/lib/python3.12/site-packages/sklearn/model_selection/_search.py:546, in BaseSearchCV.predict(self, X)
#     528 """Call predict on the estimator with the best found parameters.
#     529
#     530 Only available if ``refit=True`` and the underlying estimator supports
#    (...)
# ...

# %% [markdown]
# ### Model 5 - Lasso Regression with all features

# %%
lasso = Lasso()

# what is the best alpha ?
parameters = {'alpha':[0.0001, 0.001,0.01,0.1,1,10]}

lasso_regressor = GridSearchCV(lasso,parameters, cv=5)

lasso_regressor.fit(Xall_train,Y_train)

print(lasso_regressor.best_params_)

# %%
# model evaluation for training set
y_train_predict = lasso_regressor.predict(Xall_train)
rmse = (np.sqrt(mean_squared_error(Y_train, y_train_predict)))
mse = mean_squared_error(Y_train, y_train_predict)
r2 = r2_score(Y_train, y_train_predict)

print("The model performance for training set with lasso regressor")
print("--------------------------------------")
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
print('MSE is {}'.format(mse))
print("\n")

# model evaluation for testing set
y_test_predict = lasso_regressor.predict(Xall_test)
rmse = (np.sqrt(mean_squared_error(Y_test, y_test_predict)))
mse = mean_squared_error(Y_test, y_test_predict)
r2 = r2_score(Y_test, y_test_predict)

print("The model performance for testing set with lasso regressor")
print("--------------------------------------")
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
print('MSE is {}'.format(mse))
print("\n")

# %%
XnoCorrelated = boston.drop(columns=['lstat', 'rm'])

print(XnoCorrelated.shape)  #(506, 13)
print(Y.shape)

# %%
# Split data into train and test sets
XnoCorrelated_train, XnoCorrelated_test, Y_train, Y_test = train_test_split(XnoCorrelated, Y, test_size = 0.2, random_state = 5)

# check the dimensions of X_train, X_test, Y_train, Y_test
print("XnoCorrelated train shape:", XnoCorrelated_train.shape)
print("XnoCorrelated test shape:", XnoCorrelated_test.shape)
print("Y train shape:", Y_train.shape)
print("Y test shape:", Y_test.shape)

# standardize the data
mean = XnoCorrelated_train.mean(axis=0)
std = XnoCorrelated_train.std(axis=0)
XnoCorrelated_train = (XnoCorrelated_train-mean )/std

# NOTE: Test data is standardized with mean and std computed from training data !!!
XnoCorrelated_test = (XnoCorrelated_test-mean )/std

print("XnoCorrelated_train normalized:\n", XnoCorrelated_train)
print("XnoCorrelated_test normalized:\n", XnoCorrelated_test)

# %%
ridge = Ridge()
parameters = {'alpha':[0.0001, 0.001,0.01,0.1,1,10]}

ridge_regressor = GridSearchCV(ridge,parameters, cv=5)

ridge_regressor.fit(XnoCorrelated_train,Y_train)

print(ridge_regressor.best_params_)

# %%
# model evaluation for training set
# Compute RMSE, R2 score, MSE for the training data
y_train_predict = ridge_regressor.predict(XnoCorrelated_train)
rmse = (np.sqrt(mean_squared_error(Y_train, y_train_predict)))
mse = mean_squared_error(Y_train, y_train_predict)
r2 = r2_score(Y_train, y_train_predict)

print("The model performance for training set with ridge regressor")
print("--------------------------------------")
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
print('MSE is {}'.format(mse))
print("\n")

# model evaluation for testing set
# Compute RMSE, R2 score, MSE for the testing data
y_test_predict = ridge_regressor.predict(XnoCorrelated_test)
rmse = (np.sqrt(mean_squared_error(Y_test, y_test_predict)))
mse = mean_squared_error(Y_test, y_test_predict)
r2 = r2_score(Y_test, y_test_predict)

print("The model performance for testing set with ridge regressor")
print("--------------------------------------")
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
print('MSE is {}'.format(mse))
print("\n")

# %%
lasso = Lasso()

# what is the best alpha ?
parameters = {'alpha':[0.0001, 0.001,0.01,0.1,1,10]}

lasso_regressor = GridSearchCV(lasso,parameters, cv=5)

lasso_regressor.fit(XnoCorrelated_train,Y_train)

print(lasso_regressor.best_params_)

# %%
# model evaluation for training set
y_train_predict = lasso_regressor.predict(XnoCorrelated_train)
rmse = (np.sqrt(mean_squared_error(Y_train, y_train_predict)))
mse = mean_squared_error(Y_train, y_train_predict)
r2 = r2_score(Y_train, y_train_predict)

print("The model performance for training set with lasso regressor")
print("--------------------------------------")
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
print('MSE is {}'.format(mse))
print("\n")

# model evaluation for testing set
y_test_predict = lasso_regressor.predict(XnoCorrelated_test)
rmse = (np.sqrt(mean_squared_error(Y_test, y_test_predict)))
mse = mean_squared_error(Y_test, y_test_predict)
r2 = r2_score(Y_test, y_test_predict)

print("The model performance for testing set with lasso regressor")
print("--------------------------------------")
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
print('MSE is {}'.format(mse))
print("\n")
